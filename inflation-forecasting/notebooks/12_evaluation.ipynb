# %% [markdown]
# # 12. Model Evaluation & Comparison
#
# **Mục đích:** So sánh và đánh giá tất cả 10 mô hình
#
# **Công việc:**
# - Load kết quả từ tất cả mô hình
# - Tổng hợp RMSFE, MAPE
# - Tạo bảng so sánh
# - Visualizations
# - Export LaTeX table
# - Phân tích insights

# %%
# Import libraries

# %%
# Load all results

# %%
# Comparison table

# %%
# Visualizations

# %%
# Export LaTeX table

# %%
# Key insights
